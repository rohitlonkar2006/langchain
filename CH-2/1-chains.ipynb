# %% [markdown]
# ### CHAINS In langchain

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq

agent = ChatGroq(model = "qwen/qwen3-32b")

# %% [markdown]
# ### First Chain

# %%
from langchain_core.prompts import ChatPromptTemplate

# Task 1 [prompt]
prompt_template= ChatPromptTemplate.from_messages([
    ("system", "You are a helpfull assistant!"),
    ("human", "{input}")
])

# %%
# Task 2 [llm]
llm = ChatGroq(model = "qwen/qwen3-32b", temperature = 0)

# %%
#Task 3 [str parser]
from langchain_core.output_parsers import StrOutputParser

str_parser = StrOutputParser()

# %% [markdown]
# ### Manual Invocation

# %%
# template = prompt_template.invoke({"input":"what is the capital of france?"})

# res = llm.invoke(template)

# final_res = res.content
# final_res

# %% [markdown]
# ### Chain Invocation

# %%
chain = prompt_template | llm | str_parser
chain.invoke({"input":"what is the capital of france"})
# Out:
# "<think>\nOkay, the user is asking for the capital of France. Let me start by recalling basic geography. France is a country in Western Europe. I remember that major cities in France include Paris, Lyon, Marseille, and Bordeaux. Out of these, Paris is the most well-known and historically significant.\n\nWait, I should confirm if there's any chance the capital isn't Paris. Sometimes people might confuse it with other cities, but I'm pretty sure Paris has been the capital for a long time. Let me think about when France's capital was established. I believe it was during the Middle Ages, and Paris became the capital in the 13th century under King Louis IX. Since then, it's remained the capital. \n\nAre there any other cities that have been capitals? I think Orleans was a temporary capital during the Hundred Years' War, but that's not the main one. Also, during the French Revolution, there were some political changes, but Paris was still the capital. \n\nI should also consider if there's any confusion with other countries. For example, sometimes people might mix up France and Germany, but Germany's capital is Berlin. France's capital is definitely Paris. \n\nAdditionally, Paris is known for landmarks like the Eiffel Tower, the Louvre, and Notre-Dame Cathedral, which are all in Paris. That reinforces that Paris is the capital. \n\nI don't think there's any recent change in the capital. France is a unitary semi-presidential republic, and the capital hasn't changed in modern times. \n\nSo, putting it all together, the capital of France is Paris. I should present that clearly and maybe add a bit about its historical significance to be helpful.\n</think>\n\nThe capital of France is **Paris**. \n\nParis has been the capital since the 13th century and is renowned for its historical landmarks, cultural significance, and iconic attractions such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It serves as the political, economic, and cultural center of France."
