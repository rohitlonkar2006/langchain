# %% [markdown]
# ## **LLM CALL **

# %%
import os
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from dotenv import load_dotenv
load_dotenv()

client = os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.tools import tool
@tool
def get_weather(location:str) ->str:
    """Get The Weather Of Any Location"""
    return f"The weather in {location} is sunny"

# %%
llm = create_agent(
    model = ChatGroq(model = "qwen/qwen3-32b"),
    tools = [get_weather]
)
response = llm.invoke({"messages":"What Is The weather of india?"})

# %%
response["messages"][-1].content
# Out:
# "The current weather in India is sunny. It's a great day to enjoy outdoor activities! 🌞"
