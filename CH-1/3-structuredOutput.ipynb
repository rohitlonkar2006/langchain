# %% [markdown]
# ### Guiding in prompts

# %%
import os
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model = "qwen/qwen3-32b")

response = llm.invoke("Tell me a joke generate the output in key-value pair format with the following key: setup,punchline")
response.content
# Out:
# '<think>\nOkay, the user wants a joke in key-value pair format with setup and punchline. Let me think of a good one. Maybe something with a pun or a play on words. Let\'s see... Animals are always a safe bet. How about a cow joke? Wait, "Why did the cow win an award?" Because it was outstanding in its field. Oh, that\'s a classic. Let me check if that works. Setup: Why did the cow win an award? Punchline: Because it was outstanding in its field. Yep, that\'s a solid joke. It\'s a play on "outstanding in its field" which is a phrase often used for products, but applied to a cow here. Should be funny and appropriate. Let me make sure there\'s no typo. Setup and punchline keys are correct. Alright, that should do it.\n</think>\n\n{\n  "setup": "Why did the cow win an award?",\n  "punchline": "Because it was outstanding in its field!"\n}'

# %% [markdown]
# ### Structured output using pydentic models

# %%
from pydantic import BaseModel, Field

class llm_schema(BaseModel):
    setup: str = Field(description= "The setup for the capital of india")
    punchline: str = Field(description="the punchline for the capital of india")
      
llm_structured_op = llm.with_structured_output(llm_schema)
llm_structured_op.invoke("tell me a capital of india")
# Out:
# llm_schema(setup='What is the capital of India?', punchline='New Delhi!')

# %% [markdown]
# ### Using TypedDict

# %%
from typing_extensions import TypedDict

class llm_schema_td(TypedDict):
    setup:str
    punchline:str

obj

# %%
from langchain.agents import create_agent
from langchain_groq import ChatGroq
import os
